# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
'''Assumes csv file contains header'''
IMUWPower   = "TestingData\\withpower.csv"
IMUWTorque  = "TestingData\\withTorque.csv"
IMUPos      = "TestingData\\poscontrol.csv"
IMUVel      = "TestingData\\velcontrol.csv"

servoPos    = "TestingData\\servoPosTest.csv"
servoVel    = "TestingData\\servoVelTest.csv"

data_frame = pd.read_csv(IMUWPower, sep = ', ', header=0)
data_frame[['time']] = data_frame[['time']] - data_frame[['time']].iloc[0]
data_frame.set_index('time').plot(subplots=True)


data_frame = pd.read_csv(IMUWTorque, sep = ', ', header=0)
data_frame[['time']] = data_frame[['time']] - data_frame[['time']].iloc[0]
data_frame.set_index('time').plot(subplots=True)


data_frame = pd.read_csv(servoPos, sep = ', ', header=0)
data_frame[['time']] = data_frame[['time']] - data_frame[['time']].iloc[0]
data_frame.set_index('time').plot(subplots=True)

data_frame = pd.read_csv(IMUPos, sep = ', ', header=0)
data_frame[['time']] = data_frame[['time']] - data_frame[['time']].iloc[0]
data_frame.set_index('time').plot(subplots=True)

data_frame = pd.read_csv(IMUVel, sep = ', ', header=0)
data_frame[['time']] = data_frame[['time']] - data_frame[['time']].iloc[0]
data_frame.set_index('time').plot(subplots=True)

data_frame = pd.read_csv(servoVel, sep = ', ', header=0)
data_frame[['time']] = data_frame[['time']] - data_frame[['time']].iloc[0]
data_frame.set_index('time').plot(subplots=True)

plt.show()
# Out:
# C:\Users\marlinn\AppData\Local\Temp\ipykernel_2536\1150306338.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_frame = pd.read_csv(IMUWPower, sep = ', ', header=0)
# C:\Users\marlinn\AppData\Local\Temp\ipykernel_2536\1150306338.py:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_frame = pd.read_csv(IMUWTorque, sep = ', ', header=0)
# ...

# %%
#correlation plot????
'''Assumes csv file contains header'''
IMUVel      = "TestingData\\velcontrol copy.csv"
servoVel    = "TestingData\\servoVelTest copy.csv"

data_frame = pd.read_csv(IMUVel, sep = ', ', header=0)
data_frame[['time']] = data_frame[['time']] - data_frame[['time']].iloc[0]
data_frame.set_index('time').plot(subplots=True)

data_frame = pd.read_csv(servoVel, sep = ', ', header=0)
data_frame[['time']] = data_frame[['time']] - data_frame[['time']].iloc[0]
data_frame.set_index('time').plot(subplots=True)

plt.show()
# Out:
# C:\Users\marlinn\AppData\Local\Temp\ipykernel_2536\3083854994.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_frame = pd.read_csv(IMUVel, sep = ', ', header=0)
# C:\Users\marlinn\AppData\Local\Temp\ipykernel_2536\3083854994.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data_frame = pd.read_csv(servoVel, sep = ', ', header=0)
